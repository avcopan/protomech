# %%
from pathlib import Path

import automech

# %%
mech = automech.io.rmg.read.mechanism(
    rxn_inp=Path("cyclopentene_chem.inp"),
    spc_inp=Path("cyclopentene_species_dictionary.txt"),
)

print(automech.species_count(mech))
print(automech.reaction_count(mech))
# Out:
#   0%|          | 0/687 [00:00<?, ?it/s]
# 687
# 1639

# %%
spc_df = automech.species.expand_stereo(mech.species)
# Out:
#   0%|          | 0/687 [00:00<?, ?it/s]
#   0%|          | 0/1243 [00:00<?, ?it/s]

# %%
spc_df
# Out:
# shape: (1_243, 11)
# ┌────────────┬────────────┬────────────┬──────┬───┬───────────┬────────────┬───────────┬───────────┐
# │ name       ┆ smiles     ┆ amchi      ┆ spin ┆ … ┆ orig_name ┆ orig_smile ┆ orig_amch ┆ therm     │
# │ ---        ┆ ---        ┆ ---        ┆ ---  ┆   ┆ ---       ┆ s          ┆ i         ┆ ---       │
# │ str        ┆ str        ┆ str        ┆ i64  ┆   ┆ str       ┆ ---        ┆ ---       ┆ struct[8] │
# │            ┆            ┆            ┆      ┆   ┆           ┆ str        ┆ str       ┆           │
# ╞════════════╪════════════╪════════════╪══════╪═══╪═══════════╪════════════╪═══════════╪═══════════╡
# │ N2         ┆ N#N        ┆ AMChI=1/N2 ┆ 0    ┆ … ┆ N2        ┆ N#N        ┆ AMChI=1/N ┆ {200.0,60 │
# │            ┆            ┆ /c1-2      ┆      ┆   ┆           ┆            ┆ 2/c1-2    ┆ 00.0,{2,n │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ ull,null, │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ nul…      │
# │ Ar         ┆ [Ar]       ┆ AMChI=1/Ar ┆ 0    ┆ … ┆ Ar        ┆ [Ar]       ┆ AMChI=1/A ┆ {200.0,60 │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆ r         ┆ 00.0,{nul │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ l,1,null, │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ nul…      │
# │ He         ┆ [He]       ┆ AMChI=1/He ┆ 0    ┆ … ┆ He        ┆ [He]       ┆ AMChI=1/H ┆ {200.0,60 │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆ e         ┆ 00.0,{nul │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ l,null,1, │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ nul…      │
# │ Ne         ┆ [Ne]       ┆ AMChI=1/Ne ┆ 0    ┆ … ┆ Ne        ┆ [Ne]       ┆ AMChI=1/N ┆ {200.0,60 │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆ e         ┆ 00.0,{nul │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ l,null,nu │
# │            ┆            ┆            ┆      ┆   ┆           ┆            ┆           ┆ ll,…      │
# │ C5H7(1)    ┆ [C]1=CCCC1 ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ C5H7(1)   ┆ C1CC=[C]C1 ┆ AMChI=1/C ┆ {100.0,50 │
# │            ┆            ┆ H7/c1-2-4- ┆      ┆   ┆           ┆            ┆ 5H7/c1-2- ┆ 00.0,{nul │
# │            ┆            ┆ 5-3-1/h2H, ┆      ┆   ┆           ┆            ┆ 4-5-3-1/h ┆ l,null,nu │
# │            ┆            ┆ …          ┆      ┆   ┆           ┆            ┆ 2H,…      ┆ ll,…      │
# │ …          ┆ …          ┆ …          ┆ …    ┆ … ┆ …         ┆ …          ┆ …         ┆ …         │
# │ S(2046)rr1 ┆ C[C@@H]1[C ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ S(2046)   ┆ O=CC1C(C)[ ┆ AMChI=1/C ┆ {100.0,50 │
# │            ┆ H][C@@H]1C ┆ H7O/c1-4-2 ┆      ┆   ┆           ┆ CH]1       ┆ 5H7O/c1-4 ┆ 00.0,{nul │
# │            ┆ =O         ┆ -5(4)3-6/h ┆      ┆   ┆           ┆            ┆ -2-5(4)3- ┆ l,null,nu │
# │            ┆            ┆ …          ┆      ┆   ┆           ┆            ┆ 6/h…      ┆ ll,…      │
# │ S(1488)z   ┆ OO/C=C\C1C ┆ AMChI=1/C5 ┆ 0    ┆ … ┆ S(1488)   ┆ OOC=CC1CC1 ┆ AMChI=1/C ┆ {100.0,50 │
# │            ┆ C1         ┆ H8O2/c6-7- ┆      ┆   ┆           ┆            ┆ 5H8O2/c6- ┆ 00.0,{nul │
# │            ┆            ┆ 2-1-5-3-4- ┆      ┆   ┆           ┆            ┆ 7-2-1-5-3 ┆ l,null,nu │
# │            ┆            ┆ …          ┆      ┆   ┆           ┆            ┆ -4-…      ┆ ll,…      │
# │ S(1488)e   ┆ OO/C=C/C1C ┆ AMChI=1/C5 ┆ 0    ┆ … ┆ S(1488)   ┆ OOC=CC1CC1 ┆ AMChI=1/C ┆ {100.0,50 │
# │            ┆ C1         ┆ H8O2/c6-7- ┆      ┆   ┆           ┆            ┆ 5H8O2/c6- ┆ 00.0,{nul │
# │            ┆            ┆ 2-1-5-3-4- ┆      ┆   ┆           ┆            ┆ 7-2-1-5-3 ┆ l,null,nu │
# │            ┆            ┆ …          ┆      ┆   ┆           ┆            ┆ -4-…      ┆ ll,…      │
# │ S(603)r0   ┆ [CH2][C@@H ┆ AMChI=1/C3 ┆ 1    ┆ … ┆ S(603)    ┆ OC([CH2])C ┆ AMChI=1/C ┆ {100.0,50 │
# │            ┆ ](C=O)O    ┆ H5O2/c1-3( ┆      ┆   ┆           ┆ =O         ┆ 3H5O2/c1- ┆ 00.0,{nul │
# │            ┆            ┆ 5)2-4/h2-3 ┆      ┆   ┆           ┆            ┆ 3(5)2-4/h ┆ l,null,nu │
# │            ┆            ┆ …          ┆      ┆   ┆           ┆            ┆ 2-3…      ┆ ll,…      │
# │ S(603)r1   ┆ [CH2][C@H] ┆ AMChI=1/C3 ┆ 1    ┆ … ┆ S(603)    ┆ OC([CH2])C ┆ AMChI=1/C ┆ {100.0,50 │
# │            ┆ (C=O)O     ┆ H5O2/c1-3( ┆      ┆   ┆           ┆ =O         ┆ 3H5O2/c1- ┆ 00.0,{nul │
# │            ┆            ┆ 5)2-4/h2-3 ┆      ┆   ┆           ┆            ┆ 3(5)2-4/h ┆ l,null,nu │
# │            ┆            ┆ …          ┆      ┆   ┆           ┆            ┆ 2-3…      ┆ ll,…      │
# └────────────┴────────────┴────────────┴──────┴───┴───────────┴────────────┴───────────┴───────────┘
