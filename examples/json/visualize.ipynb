# %%
from pathlib import Path

import automech

# %%
mech = automech.io.read(Path("full_Z_mess_v0_calc.json"))

# %%
# Display specific species by name
automech.display_species(
    mech,
    spc_vals_=["CO2(13)", "C5H6(478)"],
)
# Out:
# name: CO2(13)
# smiles: O=C=O
# name: C5H6(478)
# smiles: C=1C=CCC=1

# %%
# Display specific reactions by equation
automech.display_reactions(
    mech,
    eqs=[
        "HOCO(17) = CO(12) + OH(4)",
    ],
)
# Out:
# *********
# Reaction: HOCO(17) = CO(12) + OH(4)
# Translations:
#   smiles:
#     reactants = ['O[C]=O']
#     products = ['O=[C]', '[OH]']
# Rate parameters:
#   This work:
#     HOCO(17) = CO(12) + OH(4)                                    1.000      0.000      0.000
#         PLOG  /   0.001000  1.550E-08      2.930       8768/
#         PLOG  /   0.003000       1770     0.3400      18076/
#         PLOG  /    0.02960  2.020E+13     -1.870      22755/
#         PLOG  /    0.09870  1.680E+18     -3.050      24323/
#         PLOG  /     0.2960  2.500E+24     -4.630      27067/
#         PLOG  /     0.9870  4.540E+26     -5.120      27572/
#         PLOG  /      2.960  7.120E+28     -5.600      28535/
#         PLOG  /      9.870  5.480E+29     -5.700      28899/
#         PLOG  /      29.60  9.890E+31     -6.190      30518/
#         PLOG  /      98.70  5.740E+33     -6.530      32068/
#         PLOG  /      296.0  2.610E+33     -6.290      32231/
#         PLOG  /      987.0  6.300E+32     -5.960      32470/
# alt.Chart(...)

# %%
# Display all species
automech.display_species(mech)

# %%
# Display all reactions
automech.display_reactions(mech)
